// %%
#!import "../0-setup/Packages.ipynb"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.12.1</span></li><li><span>Jinaga.Graphviz, 0.12.1</span></li><li><span>Jinaga.UnitTest, 0.12.1</span></li></ul></div></div>

// %% [markdown]
// ## Venue
//
// The user can create, delete, and restore venues.

// %%
[FactType("Festify.Environment")]
public record Environment(string environmentName);

[FactType("Festify.Venue")]
public record Venue(Environment environment, Guid venueGuid);

[FactType("Festify.Venue.Delete")]
public record VenueDelete(Venue venue);

[FactType("Festify.Venue.Restore")]
public record VenueRestore(VenueDelete delete);

Renderer.RenderTypes(typeof(VenueRestore))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 9.0.0 (20230911.1827)
//  -->
// <!-- Pages: 1 -->
// <svg width="195pt" height="307pt"
//  viewBox="0.00 0.00 194.96 307.25" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 303.25)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-303.25 190.96,-303.25 190.96,4 -4,4"/>
// <!-- Festify.Venue.Restore -->
// <g id="node1" class="node">
// <title>Festify.Venue.Restore</title>
// <ellipse fill="none" stroke="black" cx="93.48" cy="-18" rx="93.48" ry="18"/>
// <text text-anchor="middle" x="93.48" y="-12.57" font-family="Times New Roman,serif" font-size="14.00">Festify.Venue.Restore</text>
// </g>
// <!-- Festify.Venue.Delete -->
// <g id="node2" class="node">
// ...

// %% [markdown]
// ## Venue Edit
//
// The user can change the venue name.

// %%
[FactType("Festify.Venue.Name")]
public record VenueName(Venue venue, string value, VenueName[] prior);

Renderer.RenderTypes(typeof(VenueName))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 9.0.0 (20230911.1827)
//  -->
// <!-- Pages: 1 -->
// <svg width="229pt" height="220pt"
//  viewBox="0.00 0.00 228.74 219.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 215.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-215.5 224.74,-215.5 224.74,4 -4,4"/>
// <!-- Festify.Venue.Name -->
// <g id="node1" class="node">
// <title>Festify.Venue.Name</title>
// <ellipse fill="none" stroke="black" cx="85.99" cy="-18" rx="85.99" ry="18"/>
// <text text-anchor="middle" x="85.99" y="-12.57" font-family="Times New Roman,serif" font-size="14.00">Festify.Venue.Name</text>
// </g>
// <!-- Festify.Venue.Name&#45;&gt;Festify.Venue.Name -->
// <g id="edge2" class="edge">
// ...
