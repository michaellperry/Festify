// %%
#!import "../0-setup/Packages.ipynb"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.12.1</span></li><li><span>Jinaga.Graphviz, 0.12.1</span></li><li><span>Jinaga.UnitTest, 0.12.1</span></li></ul></div></div>

// %%
[FactType("Festify.Environment")]
public record Environment(User creator, string environmentName);

[FactType("Fesitfy.Administrator")]
public record Administrator(User user, Environment environment, DateTime createdAt);

[FactType("Festify.Administrator.Revoke")]
public record RevokeAdministrator(Administrator administrator);

Renderer.RenderTypes(typeof(Environment), typeof(Administrator), typeof(RevokeAdministrator))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 9.0.0 (20230911.1827)
//  -->
// <!-- Pages: 1 -->
// <svg width="274pt" height="307pt"
//  viewBox="0.00 0.00 273.92 307.25" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 303.25)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-303.25 269.92,-303.25 269.92,4 -4,4"/>
// <!-- Festify.Environment -->
// <g id="node1" class="node">
// <title>Festify.Environment</title>
// <ellipse fill="none" stroke="black" cx="85.49" cy="-193.5" rx="85.49" ry="18"/>
// <text text-anchor="middle" x="85.49" y="-188.07" font-family="Times New Roman,serif" font-size="14.00">Festify.Environment</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// ...
