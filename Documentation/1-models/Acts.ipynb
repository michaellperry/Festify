// %%
#!import "../0-setup/Packages.ipynb"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.12.1</span></li><li><span>Jinaga.Graphviz, 0.12.1</span></li><li><span>Jinaga.UnitTest, 0.12.1</span></li></ul></div></div>

// %% [markdown]
// ## Act
//
// An Act represents an artist, group, or company that is the primary performer in an event.
// The promoter can create, delete, and restore an act.
// They can also update the act's title and image.

// %%
[FactType("Festify.Environment")]
public record Environment(string environmentName);

[FactType("Festify.Act")]
public record Act(Environment environment, Guid actGuid);

[FactType("Festify.Act.Title")]
public record ActTitle(Act act, string value, ActTitle[] prior);

[FactType("Festify.Act.Image")]
public record ActImage(Act act, string imageHash, ActImage[] prior);

[FactType("Festify.Act.Delete")]
public record ActDelete(Act act, DateTime deletedAt);

[FactType("Festify.Act.Restore")]
public record ActRestore(ActDelete delete);

Renderer.RenderTypes(typeof(Environment), typeof(Act), typeof(ActTitle), typeof(ActImage), typeof(ActDelete), typeof(ActRestore))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="600pt" height="310pt"
//  viewBox="0.00 0.00 600.40 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 596.4,-305.5 596.4,4 -4,4"/>
// <!-- Festify.Environment -->
// <g id="node1" class="node">
// <title>Festify.Environment</title>
// <ellipse fill="none" stroke="black" cx="287.82" cy="-283.5" rx="87.18" ry="18"/>
// <text text-anchor="middle" x="287.82" y="-278.45" font-family="Times,serif" font-size="14.00">Festify.Environment</text>
// </g>
// <!-- Festify.Act -->
// <g id="node2" class="node">
// <title>Festify.Act</title>
// <ellipse fill="none" stroke="black" cx="287.82" cy="-195" rx="51.86" ry="18"/>
// <text text-anchor="middle" x="287.82" y="-189.95" font-family="Times,serif" font-size="14.00">Festify.Act</text>
// </g>
// <!-- Festify.Act&#45;&gt;Festify.Environment -->
// <g id="edge1" class="edge">
// <title>Festify.Act&#45;&gt;Festify.Environment</title>
// <path fill="none" stroke="black" d="M287.82,-213.09C287.82,-224.74 287.82,-240.45 287.82,-253.98"/>
// <polygon fill="black" stroke="black" points="284.32,-253.64 287.82,-263.64 291.32,-253.64 284.32,-253.64"/>
// <text text-anchor="middle" x="324.2" y="-234.2" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Festify.Act.Title -->
// <g id="node3" class="node">
// <title>Festify.Act.Title</title>
// <ellipse fill="none" stroke="black" cx="71.82" cy="-106.5" rx="71.82" ry="18"/>
// <text text-anchor="middle" x="71.82" y="-101.45" font-family="Times,serif" font-size="14.00">Festify.Act.Title</text>
// </g>
// <!-- Festify.Act.Title&#45;&gt;Festify.Act -->
// <g id="edge2" class="edge">
// <title>Festify.Act.Title&#45;&gt;Festify.Act</title>
// <path fill="none" stroke="black" d="M108.96,-122.37C146.44,-137.38 204.32,-160.56 244.03,-176.46"/>
// <polygon fill="black" stroke="black" points="242.72,-179.71 253.31,-180.18 245.33,-173.21 242.72,-179.71"/>
// <text text-anchor="middle" x="208.57" y="-145.7" font-family="Times,serif" font-size="14.00"> act</text>
// </g>
// <!-- Festify.Act.Title&#45;&gt;Festify.Act.Title -->
// <g id="edge3" class="edge">
// <title>Festify.Act.Title&#45;&gt;Festify.Act.Title</title>
// <path fill="none" stroke="black" d="M136.82,-98.43C151.19,-99.19 161.65,-101.88 161.65,-106.5 161.65,-109.79 156.36,-112.1 148.14,-113.43"/>
// <polygon fill="black" stroke="black" points="147.93,-109.94 138.33,-114.42 148.63,-116.9 147.93,-109.94"/>
// <text text-anchor="middle" x="176.65" y="-101.45" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- Festify.Act.Image -->
// <g id="node4" class="node">
// <title>Festify.Act.Image</title>
// <ellipse fill="none" stroke="black" cx="287.82" cy="-106.5" rx="77.97" ry="18"/>
// <text text-anchor="middle" x="287.82" y="-101.45" font-family="Times,serif" font-size="14.00">Festify.Act.Image</text>
// </g>
// <!-- Festify.Act.Image&#45;&gt;Festify.Act -->
// <g id="edge4" class="edge">
// <title>Festify.Act.Image&#45;&gt;Festify.Act</title>
// <path fill="none" stroke="black" d="M287.82,-124.59C287.82,-136.24 287.82,-151.95 287.82,-165.48"/>
// <polygon fill="black" stroke="black" points="284.32,-165.14 287.82,-175.14 291.32,-165.14 284.32,-165.14"/>
// <text text-anchor="middle" x="297.57" y="-145.7" font-family="Times,serif" font-size="14.00"> act</text>
// </g>
// <!-- Festify.Act.Image&#45;&gt;Festify.Act.Image -->
// <g id="edge5" class="edge">
// <title>Festify.Act.Image&#45;&gt;Festify.Act.Image</title>
// <path fill="none" stroke="black" d="M358.55,-98.49C373.23,-99.34 383.79,-102.01 383.79,-106.5 383.79,-109.73 378.33,-112.02 369.81,-113.36"/>
// <polygon fill="black" stroke="black" points="369.65,-109.86 360.05,-114.35 370.36,-116.82 369.65,-109.86"/>
// <text text-anchor="middle" x="398.79" y="-101.45" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- Festify.Act.Delete -->
// <g id="node5" class="node">
// <title>Festify.Act.Delete</title>
// <ellipse fill="none" stroke="black" cx="509.82" cy="-106.5" rx="78.48" ry="18"/>
// <text text-anchor="middle" x="509.82" y="-101.45" font-family="Times,serif" font-size="14.00">Festify.Act.Delete</text>
// </g>
// <!-- Festify.Act.Delete&#45;&gt;Festify.Act -->
// <g id="edge6" class="edge">
// <title>Festify.Act.Delete&#45;&gt;Festify.Act</title>
// <path fill="none" stroke="black" d="M471.15,-122.57C432.35,-137.69 372.66,-160.95 332.01,-176.78"/>
// <polygon fill="black" stroke="black" points="330.79,-173.5 322.75,-180.39 333.34,-180.02 330.79,-173.5"/>
// <text text-anchor="middle" x="427.57" y="-145.7" font-family="Times,serif" font-size="14.00"> act</text>
// </g>
// <!-- Festify.Act.Restore -->
// <g id="node6" class="node">
// <title>Festify.Act.Restore</title>
// <ellipse fill="none" stroke="black" cx="509.82" cy="-18" rx="82.57" ry="18"/>
// <text text-anchor="middle" x="509.82" y="-12.95" font-family="Times,serif" font-size="14.00">Festify.Act.Restore</text>
// </g>
// <!-- Festify.Act.Restore&#45;&gt;Festify.Act.Delete -->
// <g id="edge7" class="edge">
// <title>Festify.Act.Restore&#45;&gt;Festify.Act.Delete</title>
// <path fill="none" stroke="black" d="M509.82,-36.09C509.82,-47.74 509.82,-63.45 509.82,-76.98"/>
// <polygon fill="black" stroke="black" points="506.32,-76.64 509.82,-86.64 513.32,-76.64 506.32,-76.64"/>
// <text text-anchor="middle" x="527.82" y="-57.2" font-family="Times,serif" font-size="14.00"> delete</text>
// </g>
// </g>
// </svg>
